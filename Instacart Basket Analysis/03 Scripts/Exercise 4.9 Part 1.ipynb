# %% [markdown]
# # Exercise 4.9 Part 1

# %% [markdown]
# ## Contents

# %% [markdown]
# #### 01. Import libraries and data
# #### 02. Wrangle data
# #### 03. Data quality and consistency checks
# #### 04. Combine customer data with prepared data
# #### 05. Export data

# %% [markdown]
# ## 01. Import libraries and data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Import data

customer_df = pd.read_csv(r'C:\Users\lrutl\OneDrive\Desktop\Python Fundamentals for Data Analysts\Instacart Basket Analysis\02 Data\Original Data\customers.csv', index_col = False)

# %%
path = r'C:\Users\lrutl\OneDrive\Desktop\Python Fundamentals for Data Analysts\Instacart Basket Analysis'

# %%
# Check data import

customer_df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# Check data import shape

customer_df.shape
# Out:
# (206209, 10)

# %% [markdown]
# ## 02. Wrangle data

# %%
# Delete date_joined variable due to lack of necessity

customer_df = customer_df.drop(columns = ['date_joined'])

# %%
# Change user_id column name to customer_id (to match orders data)

customer_df.rename(columns = {'user_id' : 'customer_id'}, inplace = True)

# %%
# Check column name change

customer_df.head()
# Out:
#    customer_id First Name    Surnam  Gender       STATE  Age  n_dependants  \
# 0        26711    Deborah  Esquivel  Female    Missouri   48             3
# 1        33890   Patricia      Hart  Female  New Mexico   36             0
# 2        65803    Kenneth    Farley    Male       Idaho   35             2
# 3       125935   Michelle     Hicks  Female        Iowa   40             0
# 4       130797        Ann   Gilmore  Female    Maryland   26             1
#
#   fam_status  income
# 0    married  165665
# 1     single   59285
# 2    married   99568
# 3     single   42049
# 4    married   40374

# %%
# Change Surnam column name to Last Name

customer_df.rename(columns = {'Surnam' : 'Last Name'}, inplace = True)

# %%
# Change STATE column name to State

customer_df.rename(columns = {'STATE' : 'State'}, inplace = True)

# %%
# Change n_dependants column name to number_of_dependants

customer_df.rename(columns = {'n_dependants' : 'number_of_dependants'}, inplace = True)

# %%
# Check column changes

customer_df.head()
# Out:
#    customer_id First Name Last Name  Gender       State  Age  \
# 0        26711    Deborah  Esquivel  Female    Missouri   48
# 1        33890   Patricia      Hart  Female  New Mexico   36
# 2        65803    Kenneth    Farley    Male       Idaho   35
# 3       125935   Michelle     Hicks  Female        Iowa   40
# 4       130797        Ann   Gilmore  Female    Maryland   26
#
#    number_of_dependants fam_status  income
# 0                     3    married  165665
# 1                     0     single   59285
# 2                     2    married   99568
# 3                     0     single   42049
# 4                     1    married   40374

# %%
# Describe data

customer_df.describe()
# Out:
#          customer_id            Age  number_of_dependants         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %%
# Change customer_id data type to string

customer_df['customer_id'] = customer_df['customer_id'].astype('str')

# %%
# Describe data

customer_df.describe()
# Out:
#                  Age  number_of_dependants         income
# count  206209.000000         206209.000000  206209.000000
# mean       49.501646              1.499823   94632.852548
# std        18.480962              1.118433   42473.786988
# min        18.000000              0.000000   25903.000000
# 25%        33.000000              0.000000   59874.000000
# 50%        49.000000              1.000000   93547.000000
# 75%        66.000000              3.000000  124244.000000
# max        81.000000              3.000000  593901.000000

# %%
# Check new customer_id data type

customer_df['customer_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## 03. Data quality and consistency checks

# %%
# Check for mixed-type data

for col in customer_df.columns.tolist():
  weird = (customer_df[[col]].applymap(type) != customer_df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (customer_df[weird]) > 0:
    print (col)
# Out:
# First Name

# %%
# Change 'First Name' column data type to string

customer_df['First Name'] = customer_df['First Name'].astype('str')

# %%
# Check for mixed-type data

for col in customer_df.columns.tolist():
  weird = (customer_df[[col]].applymap(type) != customer_df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (customer_df[weird]) > 0:
    print (col)

# %%
# Check for missing values

customer_df.isnull().sum()
# Out:
# customer_id             0
# First Name              0
# Last Name               0
# Gender                  0
# State                   0
# Age                     0
# number_of_dependants    0
# fam_status              0
# income                  0
# dtype: int64

# %%
# Find duplicates

df_dups = customer_df[customer_df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [customer_id, First Name, Last Name, Gender, State, Age, number_of_dependants, fam_status, income]
# Index: []

# %% [markdown]
# ## 04. Combine customer data with prepared data

# %%
# Import prepared data as 'ords_prods'

ords_prods = pd.read_pickle(r'C:\Users\lrutl\OneDrive\Desktop\Python Fundamentals for Data Analysts\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged_updated_v3.pkl')

# %%
# Check customer_id data type in ords_prods

ords_prods['customer_id'].dtype
# Out:
# dtype('int64')

# %%
# Change customer_id data type to string in ords_prods df

ords_prods['customer_id'] = ords_prods['customer_id'].astype('str')

# %%
# Check ords_prods columns

ords_prods.head()
# Out:
#    order_id customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795           1             2                   3                  7
# 1    473747           1             3                   3                 12
# 2   2254736           1             4                   4                  7
# 3    431534           1             5                   4                 15
# 4   3367565           1             6                   2                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    15.0         196                  1          1   both
# 1                    21.0         196                  1          1   both
# 2                    29.0         196                  1          1   both
# 3                    28.0         196                  1          1   both
# 4                    19.0         196                  1          1   both
#
# ...

# %%
# Delete _merge column due to lack of necessity

ords_prods = ords_prods.drop(columns = ['_merge'])

# %%
ords_prods.head()
# Out:
#    order_id customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795           1             2                   3                  7
# 1    473747           1             3                   3                 12
# 2   2254736           1             4                   4                  7
# 3    431534           1             5                   4                 15
# 4   3367565           1             6                   2                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    21.0         196                  1          1
# 2                    29.0         196                  1          1
# 3                    28.0         196                  1          1
# 4                    19.0         196                  1          1
#
#   product_name  ...    price_range_loc     busiest_day    Busiest days  \
# ...

# %%
ords_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30328763 entries, 0 to 30328762
# Data columns (total 23 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   order_id                        int64
#  1   customer_id                     object
#  2   order_number                    int64
#  3   orders_day_of_week              int64
#  4   order_hour_of_day               int64
#  5   days_since_prior_order          float64
#  6   product_id                      int64
#  7   add_to_cart_order               int64
#  8   reordered                       int64
#  9   product_name                    object
#  10  aisle_id                        int64
#  11  department_id                   int64
#  12  prices                          float64
#  13  price_range_loc                 object
#  14  busiest_day                     object
#  15  Busiest days                    object
#  16  busiest_period_of_day           object
# ...

# %%
# Merge ords_prods with customer_df

ords_prods_cust = ords_prods.merge(customer_df, on = ['customer_id'], indicator = True)

# %%
ords_prods_cust['_merge'].value_counts()
# Out:
# both          30328763
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Delete _merge column due to lack of necessity

ords_prods_cust = ords_prods_cust.drop(columns = ['_merge'])

# %% [markdown]
# ## 05. Export data

# %%
# Export ords_prods_cust to Prepared data folder

ords_prods_cust.to_pickle(os.path.join(r'C:\Users\lrutl\OneDrive\Desktop\Python Fundamentals for Data Analysts\Instacart Basket Analysis\02 Data\Prepared Data\ords_prods_cust.pkl'))
