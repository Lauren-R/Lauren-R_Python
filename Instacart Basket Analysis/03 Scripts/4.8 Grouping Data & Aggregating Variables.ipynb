# %% [markdown]
# # 4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# ## 01. Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Importing Data

# %%
# Import orders_products_merged data from Prepared Data folder
ords_prods_merge = pd.read_pickle(r'C:\Users\lrutl\OneDrive\Desktop\Python Fundamentals for Data Analysts\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged_updated.pkl')

# %%
ords_prods_merge.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795            1             2                   3                  7
# 1    473747            1             3                   3                 12
# 2   2254736            1             4                   4                  7
# 3    431534            1             5                   4                 15
# 4   3367565            1             6                   2                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    15.0         196                  1          1   both
# 1                    21.0         196                  1          1   both
# 2                    29.0         196                  1          1   both
# 3                    28.0         196                  1          1   both
# 4                    19.0         196                  1          1   both
#
# ...

# %%
ords_prods_merge.shape
# Out:
# (30328763, 19)

# %%
ords_prods_merge.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795            1             2                   3                  7
# 1    473747            1             3                   3                 12
# 2   2254736            1             4                   4                  7
# 3    431534            1             5                   4                 15
# 4   3367565            1             6                   2                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    15.0         196                  1          1   both
# 1                    21.0         196                  1          1   both
# 2                    29.0         196                  1          1   both
# 3                    28.0         196                  1          1   both
# 4                    19.0         196                  1          1   both
#
# ...

# %%
# Create subset of ords_prods_merge with first 1MM rows
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head(10)
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795            1             2                   3                  7
# 1    473747            1             3                   3                 12
# 2   2254736            1             4                   4                  7
# 3    431534            1             5                   4                 15
# 4   3367565            1             6                   2                  7
# 5    550135            1             7                   1                  9
# 6   3108588            1             8                   1                 14
# 7   2295261            1             9                   1                 16
# 8   2550362            1            10                   4                  8
# 9   2968173           15            15                   1                  9
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# ...

# %% [markdown]
# ## 03. Grouping Data with Pandas

# %%
# Group by product name
df.groupby('product_name')

# %% [markdown]
# ## 04. Aggregating Data with agg()

# %%
# Split the data into groups based on "department_id". 
# Apply the agg() function to each group to obtain the mean values for the "order_number" column.
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                19.765396
# 7                18.575283
# 13               18.950838
# 14               20.460336
# 16               20.262396
# 17               12.646785
# 19               20.168036
# 20               18.808671

# %%
# Get order_number mean, min and max by department_id
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                19.765396   2  99
# 7                18.575283   2  99
# 13               18.950838   2  99
# 14               20.460336   2  99
# 16               20.262396   2  99
# 17               12.646785   2  98
# 19               20.168036   2  99
# 20               18.808671   2  99

# %% [markdown]
# ## 05. Aggregating Data with transform()

# %%
# 1. Split data into groups based on "user_id" column.
# 2. Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# 3. Create a new column, “max_order,” into which you’ll place the results of your aggregation.
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['customer_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  customer_id  order_number  orders_day_of_week  \
# 0    2398795            1             2                   3
# 1     473747            1             3                   3
# 2    2254736            1             4                   4
# 3     431534            1             5                   4
# 4    3367565            1             6                   2
# 5     550135            1             7                   1
# 6    3108588            1             8                   1
# 7    2295261            1             9                   1
# 8    2550362            1            10                   4
# 9    2968173           15            15                   1
# 10   1870022           15            17                   2
# 11   1911383           15            18                   2
# 12   2715276           15            21                   1
# 13    487368           15            22                   1
# 14   2293453           19             2                   5
#
# ...

# %%
# Remove Pandas limit to display rows
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  customer_id  order_number  orders_day_of_week  \
# 0    2398795            1             2                   3
# 1     473747            1             3                   3
# 2    2254736            1             4                   4
# 3     431534            1             5                   4
# 4    3367565            1             6                   2
# 5     550135            1             7                   1
# 6    3108588            1             8                   1
# 7    2295261            1             9                   1
# 8    2550362            1            10                   4
# 9    2968173           15            15                   1
# 10   1870022           15            17                   2
# 11   1911383           15            18                   2
# 12   2715276           15            21                   1
# 13    487368           15            22                   1
# 14   2293453           19             2                   5
# ...

# %% [markdown]
# ## 06. Deriving Columns with loc()

# %%
# Create flag to assign a "loyalty" label to a user ID based on corresponding max order value.
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['customer_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     customer_id      loyalty_flag  order_number
# 0             1      New customer             2
# 1             1      New customer             3
# 2             1      New customer             4
# 3             1      New customer             5
# 4             1      New customer             6
# 5             1      New customer             7
# 6             1      New customer             8
# 7             1      New customer             9
# 8             1      New customer            10
# 9            15  Regular customer            15
# 10           15  Regular customer            17
# 11           15  Regular customer            18
# 12           15  Regular customer            21
# 13           15  Regular customer            22
# 14           19      New customer             2
# 15           19      New customer             5
# 16           19      New customer             7
# 17           21  Regular customer            10
# 18           31  Regular customer            10
# ...

# %% [markdown]
# ## 07. Export df in pickle format

# %%
ords_prods_merge.to_pickle(os.path.join(r'C:\Users\lrutl\OneDrive\Desktop\Python Fundamentals for Data Analysts\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged_updated_v2.pkl'))
